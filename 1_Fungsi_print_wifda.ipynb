# %% [markdown]
# <a href="https://colab.research.google.com/github/Rulyta/KKA-X-Semester-1/blob/main/1_Fungsi_print_wifda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Wifda rulyta rahma aqila
#
# Kelas:x.11
#
# No.Absen:37

# %% [markdown]
# #menampilkan tkes bebas

# %%
print("wifda rulyta rahma aqila")
# Out:
# wifda rulyta rahma aqila

# %% [markdown]
# #menampilkan nilai variabel

# %%
nama_saudara="wafda rulyta"

print(nama_saudara)
# Out:
# wafda rulyta

# %%
jumlah_saudara=3

print(jumlah_saudara)
# Out:
# 3

# %% [markdown]
# #menampilkan tkes bebas dan nilai variabel

# %% [markdown]
# #menampilkan tkes bebas dan nilai variabel menggunkan tanda koma

# %%
print("saya memiliki saudara sebanyak", jumlah_saudara, "nama saudara saya adalah", nama_saudara)
# Out:
# saya memiliki saudara sebanyak 3 nama saudara saya adalah wafda rulyta

# %% [markdown]
# #menampilkan tkes bebas dan nilai variabel menggunakan tanda plus

# %%
print("saya memiliki saudara sebanyak "+str(jumlah_saudara)+". "+" nama saudara saya adalah "+nama_saudara+".")
# Out:
# saya memiliki saudara sebanyak 3.  nama saudara saya adalah wafda rulyta.

# %% [markdown]
# #Menampilkan Tkes Bebas dan Nilai Variabel Menggunakan f String

# %%
print(f"saya memiliki saudara sebanyak {jumlah_saudara}. nama saudara saya adalah {nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak 3. nama saudara saya adalah wafda rulyta.

# %% [markdown]
# #Escape Character

# %%
print("Nama: Wifda Rulyta")
print("Kelas: x.11")
print("No absen: 37")
# Out:
# Nama: Wifda Rulyta
# Kelas: x.11
# No absen: 37

# %%
print("Nama: Wifda Rulyta\nKelas: x.11\nNo absen: 37")
# Out:
# Nama: Wifda Rulyta
# Kelas: x.11
# No absen: 37

# %%
print("""Nama\t\t: Wifda Rulyta
Kelas\t\t: x.11
No absen\t: 37""")
# Out:
# Nama		: Wifda Rulyta
# Kelas		: x.11
# No absen	: 37

# %%
print("Wifda Rulyta")
# Out:
# Wifda Rulyta

# %%
print('Habib Ja\'far')
# Out:
# Habib Ja'far

# %%
print("Habib Ja'far")
# Out:
# Habib Ja'far

# %%
print('Bu Shinta berkata, "Harap fokus menyimak!".')
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print("Bu Shinta berkata, \"Harap fokus menyimak!\".")

# %%
print("Lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# #Fungsi Parameter

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"

print(nama_siswa_1)
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Daffanes
# Adzka
# Haidar

# %% [markdown]
# #Latihan soal:
# #Gunakan parameter end untuk menampilkan tulisan sebagai berikut:
# #Haidar#Adzka#Daffanes#Adzka

# %%
print(nama_siswa_3, end="-")
print(nama_siswa_2, end="-")
print(nama_siswa_1, end="-")
print(nama_siswa_2, )
# Out:
# Haidar-Adzka-Daffanes-Adzka
