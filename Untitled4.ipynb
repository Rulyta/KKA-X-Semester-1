# %% [markdown]
# <a href="https://colab.research.google.com/github/Rulyta/KKA-X-Semester-1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Wifda Rulyta Rahma Aqila
#
# Kelas:X11
#
# No absen:37

# %% [markdown]
# #Menampilkan teks bebas

# %%
print("wifda rulyta rahma aqila")
# Out:
# wifda rulyta rahma aqila

# %% [markdown]
# #Menampilkan nilai variabel

# %%
nama_saudara="wildan ruly"

print(nama_saudara)
# Out:
# wildan ruly

# %%
jumblah_saudara=2

print(jumblah_saudara)
# Out:
# 2

# %% [markdown]
# ##Menampilkan Teks Bebas dan Nilai Variabel

# %% [markdown]
# ##menampilkan teks bebas dan nilai variabel  menggunakan tanda koma

# %%
print("Saya memiliki saudara sebanyak" , jumblah_saudara,"Nama saudara saya adalah" , nama_saudara)
# Out:
# Saya memiliki saudara sebanyak 2 Nama saudara saya adalah wildan ruly

# %% [markdown]
# ##menampilkan teks bebas dan nilai variabel menggunakan tanda plus

# %%
print("saya memiliki saudara sebanyak "+str(jumblah_saudara)+". "+"nama saudara saya adalah "+nama_saudara+".")
# Out:
# saya memiliki saudara sebanyak 2. nama saudara saya adalah wildan ruly.

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan F String

# %%
print(f"saya memiliki saudara sebanyak {jumblah_saudara}. nama saudara saya adalah {nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak 2. nama saudara saya adalah wildan ruly.

# %% [markdown]
# Escape Character

# %%
print("Nama:wifda rulyta rahma aqila")
print("Kelas:X11")
print("No absen:37")
# Out:
# Nama:wifda rulyta rahma aqila
# Kelas:X11
# No absen:37

# %%
print("Nama:wifda rulyta rahma aqila\nkelas:X11nNo.Absen 37")
# Out:
# Nama:wifda rulyta rahma aqila
# kelas:X11nNo.Absen 37

# %%
print("""Nama\t\t:Wifda rulyta rahma aqila
Kelas\t\t:X.11
No absen\t:37""")
# Out:
# Nama		:Wifda rulyta rahma aqila
# Kelas		:X.11
# No absen	:37

# %%
print("wifda rulyta")
# Out:
# wifda rulyta

# %%
print('habib ja\'far')
# Out:
# habib ja'far

# %%
print("habib ja'far")
# Out:
# habib ja'far

# %%
print('Bu Shinta berkata, "harap fokus menyimak!".')
# Out:
# Bu Shinta berkata, "harap fokus menyimak!".

# %%
print("Bu Shinta berkata, \"harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata, "harap fokus menyimak!".

# %%
print("lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# #Fungsi Parameter

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"

print(nama_siswa_1)
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Daffanes
# Adzka
# Haidar

# %%
print(nama_siswa_1, end=" ")
print(nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_3, end=" ")
print(nama_siswa_2, end=" ")
print(nama_siswa_1, end=" ")
print(nama_siswa_2)
# Out:
# Haidar Adzka Daffanes Adzka
